# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The **Google Play Project: Sample Exploratory Data Analysis (EDA) Submission** typically involves analyzing the Google Play Store dataset to uncover patterns, trends, and insights. Here’s a summary of what such a project may include:
#
# ### 1. **Introduction**
# - **Objective:** Understand the dataset and extract insights to help app developers optimize their apps on the Google Play Store.
# - **Dataset Overview:** Contains information on app categories, ratings, reviews, downloads, pricing, genres, content ratings, and more.
#
# ### 2. **Data Cleaning**
# - **Handling Missing Values:** Identify and address missing or incomplete data (e.g., impute missing values or drop irrelevant records).
# - **Data Type Corrections:** Convert columns to appropriate data types (e.g., numerical, categorical, or datetime).
# - **Outlier Detection:** Identify anomalies in data (e.g., unusually high downloads or extreme prices).
#
# ### 3. **Exploratory Data Analysis**
# - **General Statistics:**
#   - Distribution of app ratings.
#   - Count of apps by category and genre.
#   - Range and average of app downloads.
#   - Pricing trends (free vs. paid apps).
# - **Visualizations:** Charts and plots to represent trends (e.g., histograms, bar plots, scatter plots).
#   - Category popularity based on installs.
#   - Relationship between app ratings and reviews or downloads.
#   - Pricing distribution across categories.
#
# ### 4. **Key Insights**
# - **Top Performing Categories:** Categories with the highest number of installs and reviews.
# - **Impact of App Features on Success:**
#   - Correlation between high ratings and frequent updates.
#   - Paid apps’ performance versus free apps.
# - **User Preferences:** Apps with the most installs are typically free, have high ratings, and belong to specific popular categories (e.g., "Games" or "Productivity").
#
# ### 5. **Challenges**
# - **Data Imbalance:** Uneven distribution of apps across categories.
# - **Inconsistent Data:** Issues like non-standardized pricing or ambiguous category labels.
#
# ### 6. **Recommendations**
# - **For Developers:**
#   - Focus on categories with high demand but low competition.
#   - Regularly update apps to maintain high ratings.
# - **For Analysts:**
#   - Investigate deeper causal relationships with advanced analytics or machine learning models.
#
# ### 7. **Conclusion**
# - Summarizes major findings and reaffirms how EDA helps in understanding the Google Play Store landscape.
#
# If you have a specific submission file, feel free to share it for a more targeted summary!

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # Exploratory Data Analysis
# The Google Play Store hosts millions of applications, each with varied user engagement, ratings, and reviews. App developers and stakeholders often face challenges in understanding how these factors impact app performance and user satisfaction. The goal of this analysis is to uncover insights that can guide developers in optimizing their app offerings and improving user experience.
#
# Key Components of the Problem Statement:
# Understanding User Sentiment and Ratings:
#
# How do app ratings and reviews reflect user satisfaction?
# What patterns emerge from user feedback in reviews?
# Exploring App Popularity and Success Factors:
#
# Which app categories or genres are most successful in terms of downloads, ratings, and reviews?
# What role do factors like price, size, and updates play in app popularity?
# Analyzing Trends and Relationships:
#
# Are there correlations between app ratings and the number of installs or reviews?
# How do free and paid apps perform across categories?
# Addressing Data Challenges:
#
# Cleaning and handling inconsistencies in the dataset.
# Identifying outliers or anomalies in app performance metrics.

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To conduct an Exploratory Data Analysis (EDA) on Play Store data, identify key trends and insights, and make recommendations to app developers and stakeholders for improving app performance and user engagement. This includes:
#
# Highlighting actionable insights for app design, pricing strategies, and update frequency.
# Suggesting areas where developers can focus their efforts to meet user needs and market demands effectively.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import files
upload = files.upload()

# %%
from google.colab import files
upload = files.upload()

# %% [markdown]
# ### Dataset First View

# %%
data1 = pd.read_csv('/content/Play Store Data new.csv')
data1

# %%
# Dataset First Look
data = pd.read_csv('/content/User Reviews.csv')
data

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape

# %%
data1.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()

# %%
num_data = data.select_dtypes(include = ['int64','float64'])
num_data

# %%
num_data.columns

# %%
cat_data = data.select_dtypes(include = ['object'])
cat_data

# %%
cat_data.columns

# %%
data1.info()

# %%
num_data1 = data1.select_dtypes(include = ['int64', 'float64'])
num_data1

# %%
num_data1.columns

# %%
cat_data1 = data1.select_dtypes(include = ['object'])
cat_data1

# %%
cat_data1.columns

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()

# %%
data1.duplicated().sum()

# %%
data.drop_duplicates(inplace = True)

# %%
data1.drop_duplicates(inplace = True)

# %%
# for final check
data.duplicated().sum()

# %%
# for final check
data1.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum()

# %%
# Missing Values/Null Values Count
data1.isnull().sum()

# %%
data.dtypes

# %%
data1.dtypes

# %%
data1['Android Ver'].mode()

# %%
data1['Android Ver'].fillna('4.1 and up',inplace = True)

# %%
data1['Current Ver'].replace('Varies with device' , np.nan , inplace = True)

# %%
data1['Current Ver'].mode()

# %%
data1['Current Ver'].fillna('1.0', inplace = True)

# %%
data1['Rating'].skew()

# %%
data1['Rating'].median()

# %%
data1['Rating'].fillna(data1['Rating'].median(),inplace = True)

# %%
data1['Type'].mode()

# %%
data1['Type'].fillna('Free',inplace = True)

# %%
data1['Content Rating'].mode()

# %%
data1['Content Rating'].fillna('Everyone', inplace = True)

# %%
# Visualising the missing value
data['Translated_Review'].mode()

# %%
data['Translated_Review'].fillna('Good' , inplace = True)

# %%
data['Sentiment'].mode()

# %%
data['Sentiment'].fillna('Positive' , inplace = True)

# %%
data['Sentiment_Polarity'].skew()

# %%
data['Sentiment_Polarity'].mean()

# %%
data['Sentiment_Polarity'].fillna(data['Sentiment_Polarity'].mean() , inplace = True)

# %%
data['Sentiment_Subjectivity'].skew()

# %%
data['Sentiment_Subjectivity'].mean()

# %%
data['Sentiment_Subjectivity'].fillna(data['Sentiment_Subjectivity'].mean(), inplace = True)

# %%
data.isnull().sum()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ### What I Know About Your Dataset:
#
# #### **Dataset Description:**
# The dataset appears to contain reviews of mobile applications along with their sentiment analysis. Here's a breakdown of its structure and content:
#
# #### **Columns in the Dataset:**
# 1. **App**
#    - Name of the application for which the review is provided.
#    - Example: *"10 Best Foods for You"* or *"Houzz Interior Design Ideas"*.
#
# 2. **Translated_Review**
#    - The text of the user’s review, possibly translated into English.
#    - Example: *"I like eat delicious food. That's I'm cooking ..."*.
#
# 3. **Sentiment**
#    - The overall sentiment derived from the review.
#    - Possible Values: *Positive, Negative, Neutral*.
#
# 4. **Sentiment_Polarity**
#    - A numerical value representing the polarity of the sentiment (positive, negative, or neutral).
#    - Range: Typically from `-1` (most negative) to `1` (most positive).
#    - Example: `1.00` indicates strong positivity.
#
# 5. **Sentiment_Subjectivity**
#    - A numerical value representing how subjective or opinion-based the review is.
#    - Range: From `0` (completely objective) to `1` (completely subjective).
#    - Example: `0.533333` suggests the review is moderately subjective.
#
# ---
#
# #### **Observations from Sample Data:**
#
# 1. **Presence of Missing Values:**
#    - Many rows have missing values in `Translated_Review`, `Sentiment`, `Sentiment_Polarity`, and `Sentiment_Subjectivity`.
#    - Example: Rows with indices `2` and `64290–64294` have all `NaN` values except for the app name.
#
# 2. **Data Distribution:**
#    - Reviews are spread across multiple apps.
#    - For the app *"10 Best Foods for You"*, reviews have been provided, but some reviews are missing.
#
# 3. **Sentiment Insights:**
#    - Sentiments are primarily *Positive* in the given examples, but the dataset might include *Negative* or *Neutral* sentiments for other reviews.
#
# 4. **Potential Data Issues:**
#    - **Sparse Data:** Many rows are missing values, particularly for apps like *"Houzz Interior Design Ideas"*.
#    - **Imbalanced Sentiments:** Sentiment classes may not be equally represented, which can bias any downstream analysis or modeling.
#
# 5. **Row Count and Structure:**
#    - Dataset likely has **64,295 rows** based on the provided indices.
#    - The data is structured and tabular, making it suitable for text analysis and sentiment classification tasks.
#
# ---
#
# ### Next Steps for Analysis:
# 1. **Data Cleaning:**
#    - Handle missing values by either imputing or dropping rows/columns with too many `NaN` values.
#    - Normalize text data in `Translated_Review` for better processing.
#
# 2. **Data Exploration:**
#    - Assess the balance of sentiment categories.
#    - Investigate the distribution of `Sentiment_Polarity` and `Sentiment_Subjectivity`.
#
# 3. **Insights Extraction:**
#    - Identify the most reviewed apps and their overall sentiment trends.
#    - Analyze the relationship between sentiment polarity and subjectivity.
#
# 4. **Visualization:**
#    - Visualize missing data patterns using heatmaps.
#    - Plot the distribution of sentiment polarities and subjectivity.
#
# Would you like guidance on cleaning or visualizing this dataset?

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns

# %%
pd.set_option('display.max_columns' , None)

# %%
# Dataset Columns
data1.columns

# %%
pd.set_option('display.max_columns' , None)

# %%
# Dataset Describe
data.describe()

# %%
# Dataset Describe
data1.describe()

# %%
data.select_dtypes(include = ['object']).describe()

# %%
data1.select_dtypes(include = ['object']).describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. App
#    - Name of the application for which the review is provided.
#    - Example: "10 Best Foods for You" or "Houzz Interior Design Ideas".
#
# 2. Translated_Review
#    - The text of the user’s review, possibly translated into English.
#    - Example: "I like eat delicious food. That's I'm cooking ...".
#
# 3. Sentiment
#    - The overall sentiment derived from the review.
#    - Possible Values: Positive, Negative, Neutral.
#
# 4. Sentiment_Polarity
#    - A numerical value representing the polarity of the sentiment (positive, negative, or neutral).
#    - Range: Typically from -1 (most negative) to 1 (most positive).
#    - Example: 1.00 indicates strong positivity.
#
# 5. Sentiment_Subjectivity
#    - A numerical value representing how subjective or opinion-based the review is.
#    - Range: From 0 (completely objective) to 1 (completely subjective).
#    - Example: 0.533333 suggests the review is moderately subjective.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
data.dtypes

# %%
data1.columns

# %%
data1['Android Ver'].unique()

# %%
data1['Current Ver'].unique()

# %%
data1['Last Updated'].unique()

# %%
data1['Genres'].unique()

# %%
data1['Content Rating'].unique()

# %%
data1['Price'].unique()

# %%
data1['Type'].unique()

# %%
data1['Installs'].unique()

# %%
data1['Size'].unique()

# %%
data1['Reviews'].unique()

# %%
data1['Rating'].unique()

# %%
data1['Category'].unique()

# %%
# Check Unique Values for each variable.
data['App'].unique()

# %%
# Check Unique Values for each variable.
data1['App'].unique()

# %%
data['App'].value_counts()

# %%
data['App'].value_counts()

# %%
data['Translated_Review'].unique()

# %%
data['Translated_Review'].value_counts()

# %%
data['Sentiment'].unique()

# %%
data['Sentiment'].value_counts()

# %%
data['Sentiment_Polarity'].unique()

# %%
data['Sentiment_Polarity'].value_counts()

# %%
data['Sentiment_Subjectivity'].unique()

# %%
data['Sentiment_Subjectivity'].value_counts()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# It sounds like you’ve already done quite a lot of preprocessing and exploration of your dataset! Here’s a structured summary of the operations you've performed and the insights you might have gained from them:
#
# ### 1. **Basic Exploration**
#    - **Shape**: Checked the dimensions of the dataset to understand the number of rows and columns.
#      - Insight: Helps to understand the dataset size and scope of analysis.
#    - **Finding columns**: Listed all column names.
#      - Insight: Useful for identifying features and their relevance.
#    - **Describe**: Summarized numerical data (mean, median, std, etc.).
#      - Insight: Identified key statistics, such as data distribution and potential outliers.
#    - **Info**: Inspected column data types and null values.
#      - Insight: Identified missing data and data type mismatches.
#
# ---
#
# ### 2. **Data Cleaning**
#    - **Finding duplicates**: Checked for redundant rows.
#      - Insight: Ensured data integrity by removing duplicate entries.
#    - **Dropping unnecessary columns**: Removed irrelevant or redundant columns.
#      - Insight: Focused the analysis on relevant features.
#    - **Handling missing values**:
#      - Used **mode**, **median**, or **mean** to fill NA values based on the context of each column.
#        - Insight: Preserved data consistency while avoiding data loss.
#    - **Replace**: Replaced specific values or corrected data inconsistencies.
#      - Insight: Standardized data for analysis.
#
# ---
#
# ### 3. **Data Type and Value Analysis**
#    - **Checking data types**: Ensured appropriate types (e.g., numeric, categorical).
#      - Insight: Identified potential type corrections.
#    - **Unique values**: Found unique values in each column.
#      - Insight: Identified categorical columns and checked for irregular values.
#    - **Categorical column identification**:
#      - Insight: Helped determine columns for one-hot encoding or label encoding for ML models.
#
# ---
#
# ### Insights That Might Have Emerged:
# 1. **Missing Value Patterns**:
#    - Which columns have the most missing data and how to handle them efficiently.
#
# 2. **Outliers**:
#    - Using descriptive statistics to spot extreme values that might need capping or transformation.
#
# 3. **Categorical vs. Numerical**:
#    - A clear separation of features based on their type to apply relevant processing techniques.
#
# 4. **Dataset Quality**:
#    - After cleaning, you've ensured the data is ready for further analysis or modeling.
#
# 5. **Consistency**:
#    - Standardizing or filling missing values with median/mode ensures consistent data quality.
#
# ---

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# scatter plot
plt.figure(figsize=(10,4))
plt.scatter(data = data , x = 'Sentiment_Polarity', y ='Sentiment_Subjectivity',color = 'red')
plt.title('Relationship between Sentiment Polarity and Sentiment Subjectivity', color = 'blue' , fontsize = 15)
plt.xlabel('Sentiment_Polarity' , color = 'green' , fontsize = 12)
plt.ylabel('Sentiment_Subjectivity', color = 'green' , fontsize = 12)
plt.tick_params(axis = 'both' , colors = 'teal' , labelsize = 10 )

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was chosen to visualize the relationship between Sentiment Polarity (x-axis) and Sentiment Subjectivity (y-axis). This chart type is appropriate because:
#
# It shows how two continuous variables are related.
# Sentiment Polarity ranges from -1 to +1 (negative to positive sentiment), while Sentiment Subjectivity ranges from 0 to 1 (objective to subjective opinions).
# The scatter plot helps identify patterns, clusters, or any correlation between these variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatter plot, the following insights can be observed:
#
# Most data points are concentrated in the positive polarity range (0 to 1), indicating that the majority of the reviews express positive sentiments.
# Subjectivity values are spread across the range (0 to 1), suggesting that reviews contain a mix of factual statements and personal opinions.
# There is no strong visible correlation between polarity and subjectivity, meaning that subjective opinions can be either positive or negative, and the same applies to objective statements.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the insights can positively impact business decisions:
#
# The predominance of positive sentiment suggests that customers generally have a favorable view of the app(s), which is encouraging for marketing and customer retention efforts.
# The mix of subjectivity indicates that customers provide both personal opinions and factual feedback. Businesses can use subjective feedback for emotional connection and factual feedback for improving product features or services.
# Identifying outliers (e.g., negative polarity with high subjectivity) can help target dissatisfied customers or address specific complaints, improving customer satisfaction.
# By leveraging these insights, businesses can focus on maintaining positive reviews, addressing negative sentiments, and tailoring their marketing and customer engagement strategies accordingly.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# bar plot
plt.figure(figsize=(10,4))
plt.bar(data = data , x = 'Sentiment', height ='Sentiment_Polarity',color = 'red')
plt.title('Comparision between Sentiment Category with Sentiment Polarity', color = 'blue' , fontsize = 15)
plt.xlabel('Sentiment_Polarity' , color = 'green' , fontsize = 12)
plt.ylabel('Sentiment_Subjectivity', color = 'green' , fontsize = 12)
plt.tick_params(axis = 'both' , colors = 'teal' , labelsize = 10 )

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart (likely a bar chart) is used to compare Sentiment Subjectivity and Sentiment Polarity across different sentiment categories (Positive, Neutral, Negative).
# Bar charts are appropriate for visualizing and comparing values across discrete categories, making it suitable for this context.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Positive Sentiment: Shows high subjectivity (close to 1), indicating opinions or personal feelings are strongly expressed.
# Negative Sentiment: Likely shows negative polarity with significant subjectivity, reflecting strong emotions or biases.
# Neutral Sentiment: Absent from this chart (or has minimal representation), possibly suggesting a data imbalance or irrelevance to the analysis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the insights can have a positive business impact in the following ways:
#
# Customer Feedback Analysis:
# Understanding subjective positive reviews can guide businesses to continue what they are doing well.
# Identifying negative reviews and addressing the underlying issues can improve customer satisfaction.
# Targeted Marketing Strategies:
# Use insights from positive subjective sentiments to create emotionally resonant marketing campaigns.
# Data Quality Improvement:
# If the neutral category is underrepresented, the dataset might need balancing for a fair sentiment analysis, leading to better insights in future campaigns.
# If you'd like to refine this analysis further or interpret it in a different way, feel free to ask!

# %% [markdown]
# #### Chart - 3

# %%
plt.figure(figsize=(10,4))
plt.hist(data['Sentiment_Polarity'],color = 'red')
plt.title('Distribution of Sentiment Polarity', color = 'blue' , fontsize = 15)
plt.xlabel('Sentiment_Polarity' , color = 'green' , fontsize = 12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart is a histogram, which is ideal for visualizing the distribution of continuous numerical data like Sentiment Polarity.
# A histogram shows the frequency of data points across a range, helping to understand how sentiment polarity is distributed (e.g., whether it's skewed or balanced around neutrality).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The sentiment polarity appears to follow a bell-shaped distribution:
# Most values are centered around 0.0 (neutral sentiment), indicating a majority of feedback is neutral.
# There is a gradual decrease in frequency as the polarity moves towards extremes like -1.0 (strongly negative) or 1.0 (strongly positive).
# Positive sentiments are more frequent than negative ones, as the histogram shows slightly higher density on the positive side.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the insights can help in several ways:
#
# Content Optimization:
# If most feedback is neutral, strategies can be developed to engage customers emotionally, driving stronger positive feedback.
# Negative Sentiment Mitigation:
# The presence of negative sentiment highlights areas requiring attention. This can inform customer service improvements or product changes.
# Market Segmentation:
# Analyzing the distribution helps in understanding customer preferences and emotional responses, enabling tailored marketing campaigns.
# Data-Driven Decision Making:
# If positive sentiment dominates, it indicates a strong brand reputation, which can be leveraged in advertising and promotions.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(6,3))
plt.boxplot(data['Sentiment_Subjectivity'] )
plt.title('Distribution of Sentiment Subjectivity data set for finding outlier' , color = 'green', fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is a box plot, which is ideal for visualizing the distribution of data, identifying its spread, central tendency, and detecting outliers.
# It helps to quickly summarize Sentiment Subjectivity by showing key statistics such as the median, quartiles, and range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Median: The orange line inside the box represents the median of Sentiment Subjectivity, which is approximately 0.5. This suggests that subjectivity is fairly balanced in the dataset.
# Interquartile Range (IQR): The range between the lower (Q1) and upper (Q3) quartiles indicates most of the data lies between 0.25 and 0.75, suggesting moderate subjectivity overall.
# Outliers: The whiskers extend to the minimum (0.0) and maximum (1.0), and there are no visible extreme outliers, meaning the data is clean and well-contained.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the insights can be impactful in the following ways:
#
# Understanding Subjectivity:
# If most feedback is moderately subjective, this means customers are providing a mix of opinions and facts. Businesses can leverage this balance to make informed decisions.
# Customer Insights:
# Higher subjectivity (above 0.75) might indicate emotional or opinion-heavy feedback, which could be analyzed for trends or sentiments.
# Data Quality:
# The absence of significant outliers ensures data reliability, which is crucial for accurate sentiment analysis.
# Targeted Strategy:
# Insights into customer expression styles (subjective vs. objective) can inform marketing campaigns and service personalization.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize = (10,3))
sns.countplot(x=data['Sentiment'] , color = 'red')
plt.tick_params(axis = 'x', rotation = 45, colors = 'green' , labelsize = 12)
plt.tick_params(axis = 'y' , rotation = 45 , colors = 'green' ,labelsize = 12)
plt.xlabel('Sentiment' , fontsize = 12, color = 'orchid')
plt.ylabel('Count', fontsize = 12, color = 'orchid' )
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This format makes it easy to quickly identify the predominant sentiment and gauge relative proportions between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Positive sentiment has the highest count, significantly outnumbering both Neutral and Negative sentiments. Neutral sentiment is the lowest among the three categories. Negative sentiment is higher than Neutral but still much lower than Positive. These insights suggest a generally favorable reception or sentiment

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
# es
#
# The high count of Positive sentiment indicates customer satisfaction or success in engagement strategies, which businesses can capitalize on to maintain momentum.
#
# The Negative sentiment count, although relatively low, provides actionable opportunities for improvement. Businesses can analyze the underlying causes and address them to reduce dissatisfaction.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize = (15,6))
barplot = sns.barplot(x=data1['Category'] , y = data1['Rating'] , color = 'teal')
plt.title('Comparision of Rating with respect to Category' , color = 'red' , fontsize = 12)
plt.tick_params(axis = 'x' , rotation = 90 , colors = 'blue', labelsize = 10)
for i in barplot.containers:
  barplot.bar_label(i)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen as it effectively compares the average ratings across multiple categories. This format allows for a straightforward visual representation, making it easy to spot trends and outliers among the categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most categories have a similar average rating, clustered around a certain range, indicating consistency in customer feedback across various categories.
# One category (likely "1.9") has an unusually high average rating compared to others, which stands out as an outlier.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help improve business strategies:
#
# The consistently high ratings for most categories reflect customer satisfaction, which can be leveraged to maintain loyalty and positive brand perception.
# The significantly higher rating in the outlier category suggests exceptional performance. This can serve as a benchmark for other categories, and the factors contributing to this success should be analyzed and replicated

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize = (6,3))
sns.histplot(x = data1['Rating'] , bins = 10 , kde = True )
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is a type of bar chart that visually represents the distribution of a dataset. It is commonly used in data analysis to summarize large data sets and identify patterns, trends, or outliers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 2.
# The chart shows that most ratings are clustered between 4.0 and 5.0, indicating a highly positive user sentiment. The sharp peak suggests that customers are largely satisfied. There are very few ratings beyond this range, suggesting that extreme positive or negative feedback is rare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# 3.
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, positive insights:
#
# The concentration of ratings between 4.0 and 5.0 reflects strong customer satisfaction, which can be leveraged in marketing campaigns to attract new customers. Understanding what drives such high satisfaction could help the business replicate those successful practices across other areas.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize = (5 , 3))
sns.violinplot(x = data1['Rating'] )
plt.title("Distribution of Rating and finding outlier")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot is a data visualization tool that combines features of a box plot and a kernel density plot to display the distribution of data. It’s particularly useful for comparing the distribution of data across different categories. A violin plot would show how the scores are distributed in each school (e.g., whether most scores are clustered around a particular range or spread out)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The violin plot highlights the presence of outliers in the data, with ratings extending beyond the typical range (e.g., beyond 5.0 up to 20.0). These extreme values are likely anomalies or errors in data entry. The majority of the data is concentrated around ratings between 4.0 and 5.0, as indicated by the bulge near this range. The dense, narrow central region of the plot suggests that most ratings are clustered within a small range, demonstrating a consistent level of customer satisfaction./

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Yes, they can, with proper action:
#
# Improved Data Quality: Identifying and addressing outliers can lead to cleaner data, which enhances the accuracy of analyses and decision-making.
#
# Leverage Customer Satisfaction: The concentration of ratings around 4.0–5.0 reflects strong customer satisfaction, which can be promoted to attract new customers

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize = (10,6))
sns.barplot(x = data1['Category'] , y = data1['Rating'] , hue = data1['Type'])
plt.tick_params(axis = 'x' , rotation = 90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart is a bar plot showing the ratings of applications across various categories, divided into "Free," "Paid," and a third undefined category (labeled as "0"). This chart was likely chosen because it provides a clear comparison of the average ratings for different app categories, enabling the analysis of trends in app quality based on their type (Free vs. Paid).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Consistent Ratings: Ratings for most categories, whether Free or Paid, are clustered between 2.5 and 5. This suggests that app quality, as perceived by users, does not drastically vary between categories or app types.
#
# Unexpected "0" Type: The presence of the category labeled "0" with unusually high ratings (above 15) likely indicates a data error or an anomaly.
#
# Higher Paid App Ratings: In certain categories, Paid apps have marginally higher ratings compared to Free apps, implying users may perceive better quality in paid apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Focus on Paid Apps in Select Categories: Since paid apps show slightly higher ratings in some categories, businesses could emphasize premium versions in these segments to attract quality-focused users.
#
# The unexplained spike in "0" ratings above 15 could undermine the validity of the insights and impact decision-making if not investigated. Data errors can mislead stakeholders.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize = (6,3))
sns.kdeplot(x=data['Sentiment_Subjectivity'] , color = 'teal')
plt.title('KDE of Sentiment Subjectivity' , fontsize =15 , color = 'red')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Kernel Density Estimation (KDE) chart was chosen to visualize the distribution of sentiment subjectivity across the data. KDE plots are effective in showing patterns in the data's density, making it easier to identify where sentiment values are concentrated, from objective (close to 0) to highly subjective (close to 1).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There are notable peaks at different levels of subjectivity, with the highest density around 0.4–0.6, indicating that many data points exhibit moderate subjectivity.
# There is also a smaller concentration of highly subjective content near 1 and more objective sentiment near 0.
# This suggests a diverse range of subjectivity in the sentiments being analyzed, potentially pointing to varied customer feedback tones.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help businesses better understand customer sentiment:
#
# If moderate subjectivity dominates, it may indicate that customers are expressing balanced feedback that combines facts and opinions.
# Identifying areas with highly subjective sentiment could help focus on addressing emotional feedback or complaints.
# Insights into the distribution can guide targeted strategies, such as refining customer communication to balance objective details with emotional appeals.Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(6,3))
sns.countplot(x=data1['Content Rating']  ,palette = 'viridis')
plt.title('Comparision of content rating' , color = 'green' , fontsize = 15 )
plt.tick_params(axis = 'x' , rotation = 45, colors = 'red')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart is effective for showing the distribution of categorical data like content ratings. It clearly highlights the frequency of each category, making it easy to compare the popularity or usage of different ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of the content is rated "Everyone," with significantly higher counts than other categories.
# "Teen" has the second-highest count, followed by smaller segments for "Everyone 10+," "Mature 17+," "Adults only 18+," and "Unrated."
# This indicates a focus on broadly accessible content, with limited offerings for specific age groups or mature audiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can guide business decisions:
#
# A predominance of "Everyone" ratings suggests a focus on universal appeal. This can be leveraged in marketing to emphasize inclusivity.
# The relatively low counts in mature or niche categories may indicate untapped market potential for specialized content targeting older or more specific audiences.
# For a car dealership, if analogous categories like customer demographics were analyzed, similar insights could guide product offers or promotional strategies.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Scatterplot of horsepower vs. price colored by fuel-type:
plt.figure(figsize = (6,3))
sns.scatterplot(x =data['Sentiment_Polarity'], y=data1['Rating'] )
plt.title('Relationship between Sentiment_Polarity and Rating with Outlier' , color = 'teal' , fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for showing relationships between two continuous variables, in this case, sentiment polarity and rating. It effectively visualizes whether there is any correlation between customer sentiment (positive, negative, or neutral) and the given ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The data shows a concentration of points near a sentiment polarity of 0 (neutral), with ratings clustered around typical ranges (e.g., 4-5).
# There is one clear outlier in the plot where the rating significantly exceeds the expected range (above 17.5).
# The overall spread suggests no strong linear correlation between sentiment polarity and ratings, but most ratings tend to be moderate to high regardless of sentiment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, these insights could help:
#
# Understanding that ratings do not directly correlate with sentiment polarity can refine how feedback is analyzed. It indicates other factors might be influencing ratings, such as product quality or pricing.
# Identifying the outlier suggests a need to check for data quality issues or exceptional cases that might skew analysis.
# For a car dealership, analyzing customer reviews or survey data in a similar way could help isolate patterns in feedback versus ratings for vehicles or services, improving customer satisfaction initiatives.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
data1

# %%
data1['Last Updated'] = pd.to_datetime(data1['Last Updated'],errors = 'coerce')
data1['Year Updated'] = data1['Last Updated'].dt.year
data1

# %%
sns.lineplot(x=data1['Year Updated'] , y = data1['Rating'])
plt.title('Pattern of Ratings over time' , color = 'red' ,fontsize = 15)
plt.xlabel('Year' , color = 'green' , fontsize = 12)
plt.ylabel('Rating' , color = 'green' ,fontsize = 12)
plt.tick_params(axis = 'x' , rotation = 90 , colors = 'purple' , labelsize = 10)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Reason for choosing this chart:
#
# This is a line plot with a shaded region (confidence interval). It is chosen to visualize the trend or pattern of ratings over time.
#
# Line plot is ideal for analyzing continuous data like yearly ratings.
# The shaded region helps to indicate the variability or uncertainty in ratings (e.g., confidence intervals).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Trend over time:
#
# The ratings decreased significantly from 2010 to 2012, reaching the lowest point around 2012.
#
# After 2012, there is a steady recovery and an upward trend, reaching a peak in 2018.
#
# Variability:
#
# The shaded region shows higher variability or uncertainty in ratings between 2010 and 2013.
#
# After 2013, variability reduces, indicating more consistent ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact:
#
# The upward trend in ratings from 2012 to 2018 indicates consistent improvement, which reflects positively on the company’s efforts to enhance customer satisfaction, product quality, or service delivery.
#
# The steady improvement in ratings builds customer trust and brand reputation, which can be leveraged to attract new customers and retain existing ones.
#
# The reduced variability after 2013 shows a stabilization of performance, which businesses can highlight as a commitment to delivering consistent quality.
#
# Yes, the chart reveals a period of negative growth in ratings from 2010 to 2012.
# Justification:
#
# During this period, the ratings dropped sharply, reaching their lowest point in 2012 (around 3.5–3.6). This decline could be due to:
#
# Poor product or service quality.
#
# Negative customer experiences or complaints.
#
# Ineffective marketing or lack of focus on customer retention.
#
# The shaded region also indicates high variability or uncertainty during this period, suggesting inconsistent experiences across customers, which can lead to dissatisfaction and reduced loyalty.
#
# Conclusion:
#
# Positive Growth: Post-2012, the upward trend can guide businesses to focus on what worked well to drive ratings up.
#
# Negative Growth: The sharp decline from 2010–2012 signals a period of failure or mismanagement. Businesses should analyze the root causes (e.g., operational inefficiencies or customer dissatisfaction) during this period and implement corrective measures to avoid such dips in the future.
#
# #Conclusion:
#
# Positive Growth: Post-2012, the upward trend can guide businesses to focus on what worked well to drive ratings up.
#
# Negative Growth: The sharp decline from 2010–2012 signals a period of failure or mismanagement. Businesses should analyze the root causes (e.g., operational inefficiencies or customer dissatisfaction) during this period and implement corrective measures to avoid such dips in the future.

# %% [markdown]
# ## Chart - 14 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# Let us check if there is any co-relation in both the dataframes (Play store App and user reviews)

# %%
merged_df = pd.merge(data1,data, on = 'App', how = 'inner')
merged_df.head()

# %%
merged_df.drop_duplicates(inplace = True)

# %%
merged_df.duplicated().sum()

# %%
merged_df.isnull().sum()

# %%
merge_df = merged_df.select_dtypes(['int64','float64'])
merge_df

# %%
sns.pairplot(merge_df)

# %% [markdown]
# ### 1. **Why did you pick the specific chart?**
#    - This is a **pair plot**, which is a type of visualization used to explore the relationships between multiple numerical variables in a dataset.
#    - **Why chosen?**
#      - It is ideal for performing exploratory data analysis (EDA).
#      - Pair plots allow for a quick examination of both **individual distributions** (diagonal plots) and **relationships between variables** (scatter plots in off-diagonal grids).
#      - It highlights trends, correlations, or potential outliers across various variables like **Rating**, **Reviews**, **Year Updated**, **Sentiment Polarity**, and **Sentiment Subjectivity**.
#
# ---
#
# ### 2. **What is/are the insight(s) found from the chart?**
#
# #### **Individual Insights (Diagonals):**
# - **Rating**:
#   - Most of the ratings are concentrated between 3.5 and 5, with very few low ratings (<3.5).
#   - The distribution is skewed towards higher ratings.
#
# - **Reviews**:
#   - Reviews are heavily concentrated at lower values, indicating most apps have relatively fewer reviews, with only a few apps having an extremely high number of reviews (outliers).
#
# - **Year Updated**:
#   - Most apps were updated in recent years, especially in **2018**.
#
# - **Sentiment Polarity**:
#   - The distribution of sentiment polarity is roughly centered around 0, with a range from -1 (negative sentiment) to 1 (positive sentiment).
#   - Positive sentiments dominate the data (values > 0 are denser).
#
# - **Sentiment Subjectivity**:
#   - Most sentiments are towards subjectivity (closer to 1), indicating users often express personal opinions rather than objective reviews.
#
# ---
#
# #### **Pairwise Insights (Scatter Plots):**
# - **Rating vs. Reviews**:
#   - Higher ratings do not necessarily correlate with a large number of reviews, but apps with extremely high reviews tend to have ratings above 4.
#   - Apps with fewer reviews show a wide spread of ratings.
#
# - **Year Updated vs. Rating**:
#   - Recently updated apps (2018) have a higher concentration of better ratings (closer to 4-5), suggesting that updates positively influence app quality or user perception.
#
# - **Sentiment Polarity vs. Rating**:
#   - A positive correlation exists: Higher sentiment polarity (positive sentiment) aligns with higher ratings.
#   - Negative sentiment polarity is associated with lower ratings.
#
# - **Sentiment Subjectivity vs. Rating**:
#   - No strong correlation, but higher ratings tend to occur across varying levels of subjectivity.
#
# ---
#
# ### **Conclusion:**
# The pair plot effectively identifies patterns such as:
# 1. **High ratings and recent updates (2018)** correlate positively.
# 2. Positive sentiment polarity aligns with higher ratings.
# 3. Reviews are heavily skewed, with a few outliers having extremely high numbers.
# These insights can guide app developers in improving user experience by focusing on updates and addressing negative sentiment.

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
# Correlation Heatmap visualization

# %%
merge_df.corr()

# %%
sns.heatmap(merge_df.corr(), annot = True, cmap = 'coolwarm')

# %% [markdown]
# ### 1. **Why did you pick the specific chart?**
#    - The given chart is a **correlation heatmap**, used to display the degree of correlation between multiple numerical variables in a dataset.
#    - **Why chosen?**
#      - It provides a concise, visual representation of the relationships (correlations) between variables.
#      - The use of color gradients makes it easy to identify positive and negative correlations at a glance.
#      - Ideal for identifying patterns, dependencies, or lack of relationships between variables in exploratory data analysis (EDA).
#
# ---
#
# ### 2. **What is/are the insight(s) found from the chart?**
#
# #### **Key Observations:**
# - **Rating vs. Year Updated**:
#   - Correlation: **0.25 (moderate positive)**
#     - Apps that are updated more recently tend to have slightly higher ratings, indicating that updates might enhance user satisfaction.
#
# - **Rating vs. Sentiment Polarity**:
#   - Correlation: **0.074 (weak positive)**
#     - Higher positive sentiment polarity is weakly associated with higher ratings, which shows that user sentiment affects ratings but not strongly.
#
# - **Rating vs. Reviews**:
#   - Correlation: **0.07 (weak positive)**
#     - The number of reviews has a minimal impact on the overall ratings, suggesting that even apps with fewer reviews can have high ratings.
#
# - **Sentiment Polarity vs. Sentiment Subjectivity**:
#   - Correlation: **0.24 (moderate positive)**
#     - More subjective reviews (personal opinions) tend to be slightly more positive in sentiment.
#
# - **Reviews vs. Sentiment Polarity**:
#   - Correlation: **-0.094 (weak negative)**
#     - Apps with a higher number of reviews tend to have slightly lower sentiment polarity, possibly due to mixed or critical opinions from a larger user base.
#
# #### **General Insights**:
# 1. No strong correlations (values close to ±1) are observed, indicating that these variables are only weakly related to each other.
# 2. The strongest correlation (**0.25**) is between **Rating** and **Year Updated**, suggesting that regular updates positively influence user ratings.
# 3. The weakest relationships are observed between **Year Updated** and other variables, showing limited direct influence.
#
# ---
#
# ### **Conclusion**:
# The heatmap highlights weak to moderate correlations, indicating that:
# - **Year Updated** and **Sentiment Polarity** are somewhat influential on **Ratings**.
# - No single factor dominates ratings, suggesting a multifactorial influence (e.g., app quality, user preferences). These insights can guide businesses to focus on frequent updates and monitoring user sentiment for improvements.

# %% [markdown]
# ### **Solution to Business Objective**
#
# Based on the data and insights gained from the visualizations, here are actionable suggestions for the client to achieve their business objective (likely improving app performance, user satisfaction, and profitability):
#
# ---
#
# ### **1. Regular Updates**
#    - **Why?**: Apps updated more frequently have better ratings (correlation: 0.25).
#    - **Action**: Ensure regular updates that address user feedback, fix bugs, and introduce new features to maintain user engagement and satisfaction.
#
# ---
#
# ### **2. Monitor and Improve Sentiment Polarity**
#    - **Why?**: Positive sentiment polarity is weakly but positively correlated with higher ratings.
#    - **Action**: Analyze user reviews and identify common issues or requests. Use this feedback to:
#      - Enhance features or fix bugs.
#      - Create positive sentiment through prompt responses to customer feedback.
#
# ---
#
# ### **3. Encourage Quality Reviews**
#    - **Why?**: Higher numbers of reviews are not strongly linked to ratings, but reviews provide valuable qualitative data.
#    - **Action**:
#      - Encourage satisfied users to leave positive reviews by offering incentives or in-app prompts.
#      - Respond to negative reviews to showcase active customer care and potentially improve ratings.
#
# ---
#
# ### **4. Focus on Consistency**
#    - **Why?**: Variability in ratings and reviews can harm reputation.
#    - **Action**: Maintain consistent service or product quality by:
#      - Conducting periodic quality assurance.
#      - Ensuring all app versions deliver similar performance across devices.
#
# ---
#
# ### **5. Leverage Sentiment Subjectivity**
#    - **Why?**: Subjective reviews are often linked with positive sentiment (correlation: 0.24).
#    - **Action**: Highlight positive, subjective reviews in marketing campaigns to build trust and attract new users.
#
# ---
#
# ### **Summary**:
# To achieve the business objective, the client should focus on **frequent updates**, **user feedback-driven improvements**, **active engagement with reviews**, and **highlighting positive user sentiment** to drive customer satisfaction and loyalty.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
